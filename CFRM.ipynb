# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = "/content/drive/MyDrive/BTT - G&M1A/G&M/companies.csv"

df = pd.read_csv(path, low_memory=False)

df.head()
# Out:
#         id  Unnamed: 0.1 entity_type  entity_id  parent_id  \
# 0      c:1             0     Company          1        NaN
# 1     c:10             1     Company         10        NaN
# 2    c:100             2     Company        100        NaN
# 3  c:10000             3     Company      10000        NaN
# 4  c:10001             4     Company      10001        NaN
#
#                  name     normalized_name                    permalink  \
# 0            Wetpaint            wetpaint            /company/wetpaint
# 1             Flektor             flektor             /company/flektor
# 2               There               there               /company/there
# 3             MYWEBBO             mywebbo             /company/mywebbo
# 4  THE Movie Streamer  the movie streamer  /company/the-movie-streamer
#
#      category_code     status  ... first_milestone_at last_milestone_at  \
# 0              web  operating  ...         2010-09-05        2013-09-18
# 1      games_video   acquired  ...                NaN               NaN
# 2      games_video   acquired  ...         2003-02-01        2011-09-23
# 3  network_hosting  operating  ...                NaN               NaN
# 4      games_video  operating  ...                NaN               NaN
#
#   milestones relationships        created_by           created_at  \
# 0        5.0          17.0  initial-importer  2007-05-25 06:51:27
# 1        NaN           6.0  initial-importer  2007-05-31 21:11:51
# 2        4.0          12.0  initial-importer  2007-08-06 23:52:45
# 3        NaN           NaN               NaN  2008-08-24 16:51:57
# 4        NaN           NaN               NaN  2008-08-24 17:10:34
#
#             updated_at        lat         lng   ROI
# 0  2013-04-13 03:29:00  47.606209 -122.332071  15.5
# 1  2008-05-23 23:23:14  34.021122 -118.396467   NaN
# 2  2013-11-04 02:09:48  37.562992 -122.325525   NaN
# 3  2008-09-06 14:19:18        NaN         NaN   NaN
# 4  2008-09-06 14:19:18        NaN         NaN   NaN
#
# [5 rows x 44 columns]

# %%
df.shape
# Out:
# (196553, 44)

# %%
df.shape
# Out:
# Index(['id', 'Unnamed: 0.1', 'entity_type', 'entity_id', 'parent_id', 'name',
#        'normalized_name', 'permalink', 'category_code', 'status', 'founded_at',
#        'closed_at', 'domain', 'homepage_url', 'twitter_username', 'logo_url',
#        'logo_width', 'logo_height', 'short_description', 'description',
#        'overview', 'tag_list', 'country_code', 'state_code', 'city', 'region',
#        'first_investment_at', 'last_investment_at', 'investment_rounds',
#        'invested_companies', 'first_funding_at', 'last_funding_at',
#        'funding_rounds', 'funding_total_usd', 'first_milestone_at',
#        'last_milestone_at', 'milestones', 'relationships', 'created_by',
#        'created_at', 'updated_at', 'lat', 'lng', 'ROI'],
#       dtype='object')

# %%
df.dtypes
# Out:
# id                      object
# Unnamed: 0.1             int64
# entity_type             object
# entity_id                int64
# parent_id              float64
# name                    object
# normalized_name         object
# permalink               object
# category_code           object
# status                  object
# founded_at              object
# closed_at               object
# domain                  object
# homepage_url            object
# twitter_username        object
# logo_url                object
# logo_width             float64
# logo_height            float64
# short_description       object
# description             object
# overview                object
# tag_list                object
# country_code            object
# state_code              object
# city                    object
# region                  object
# first_investment_at     object
# last_investment_at      object
# investment_rounds      float64
# invested_companies     float64
# first_funding_at        object
# last_funding_at         object
# funding_rounds         float64
# funding_total_usd      float64
# first_milestone_at      object
# last_milestone_at       object
# milestones             float64
# relationships          float64
# created_by              object
# created_at              object
# updated_at              object
# lat                    float64
# lng                    float64
# ROI                    float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# id                          0
# Unnamed: 0.1                0
# entity_type                 0
# entity_id                   0
# parent_id              196553
# name                       23
# normalized_name            26
# permalink                   0
# category_code           73367
# status                      0
# founded_at             105326
# closed_at              193933
# domain                  70008
# homepage_url            70008
# twitter_username       115962
# logo_url                86443
# logo_width              86443
# logo_height             86443
# short_description      189422
# description            104505
# overview                69582
# tag_list               115101
# country_code           108563
# state_code             145650
# city                   112663
# region                      0
# first_investment_at    193970
# last_investment_at     193970
# investment_rounds      193962
# invested_companies     193962
# first_funding_at       165046
# last_funding_at        165046
# funding_rounds         164846
# funding_total_usd      168679
# first_milestone_at     104854
# last_milestone_at      104854
# milestones             104854
# relationships           66886
# created_by              41020
# created_at                  0
# updated_at                  0
# lat                    112701
# lng                    112701
# ROI                    195827
# dtype: int64

# %%
df['status'].unique()
# Out:
# array(['operating', 'acquired', 'closed', 'ipo'], dtype=object)

# %%
df['category_code'].unique()
# Out:
# array(['web', 'games_video', 'network_hosting', 'advertising',
#        'cleantech', nan, 'enterprise', 'other', 'consulting', 'mobile',
#        'health', 'software', 'analytics', 'finance', 'education',
#        'medical', 'manufacturing', 'biotech', 'ecommerce',
#        'public_relations', 'hardware', 'search', 'news', 'government',
#        'security', 'photo_video', 'travel', 'semiconductor', 'social',
#        'legal', 'transportation', 'hospitality', 'sports', 'nonprofit',
#        'fashion', 'messaging', 'music', 'automotive', 'design',
#        'real_estate', 'local', 'nanotech', 'pets'], dtype=object)

# %%
df['country_code'].unique()
# Out:
# array(['USA', nan, 'MAR', 'IND', 'AUS', 'FRA', 'JPN', 'NLD', 'EGY', 'ISR',
#        'GBR', 'THA', 'CAN', 'AUT', 'IRL', 'SWE', 'DEU', 'BRA', 'FIN',
#        'RUS', 'SGP', 'MEX', 'CHN', 'ESP', 'ISL', 'KOR', 'TUR', 'DNK',
#        'ARG', 'PAK', 'HUN', 'POL', 'GRC', 'PRT', 'BLR', 'CSS', 'MKD',
#        'CHE', 'SVN', 'UKR', 'ITA', 'NZL', 'LIE', 'NOR', 'CZE', 'VNM',
#        'HRV', 'BEN', 'CHL', 'GHA', 'ZAF', 'MYS', 'EST', 'BEL', 'SVK',
#        'TWN', 'CRI', 'HKG', 'BGD', 'BOL', 'LBN', 'LUX', 'AZE', 'COL',
#        'PHL', 'ARE', 'IDN', 'ROM', 'ANT', 'CYM', 'NGA', 'GIN', 'CYP',
#        'LKA', 'SWZ', 'VGB', 'MLT', 'SAU', 'KEN', 'BGR', 'PER', 'LVA',
#        'LAO', 'NPL', 'MDA', 'CMR', 'UGA', 'TUN', 'URY', 'MUS', 'VEN',
#        'OMN', 'ECU', 'KWT', 'JOR', 'LTU', 'ALB', 'QAT', 'UMI', 'PST',
#        'REU', 'GTM', 'PCN', 'BHS', 'GEO', 'BWA', 'DZA', 'GRD', 'ZMB',
#        'GIB', 'PAN', 'MTQ', 'PRI', 'BIH', 'DMA', 'BHR', 'SYC', 'SLE',
#        'TTO', 'VCT', 'ARA', 'BRB', 'NAM', 'SLV', 'AFG', 'BLZ', 'UZB',
#        'IRN', 'TZA', 'ARM', 'ATG', 'DOM', 'JAM', 'MDV', 'MMR', 'KAZ',
#        'GLP', 'MAC', 'IOT', 'MDG', 'KGZ', 'VIR', 'ZWE', 'PRY', 'PRK',
#        'LSO', 'SMR', 'IRQ', 'BMU', 'NRU', 'KHM', 'ETH', 'BDI', 'SEN',
#        'HMI', 'HND', 'TJK', 'NER', 'NCL', 'CUB', 'FST', 'AGO', 'NFK',
#        'NIC', 'AND', 'MCO', 'YEM', 'BRN', 'HTI', 'AIA', 'SUR', 'SYR',
#        'SOM', 'RWA', 'CIV', 'SDN'], dtype=object)

# %%
df['state_code'].unique()
# Out:
# array(['WA', 'CA', nan, 'NY', 'NM', 'TX', 'OH', 'NJ', 'IL', 'MA', 'NC',
#        'CT', 'PA', 'NH', 'MI', 'AZ', 'TN', 'GA', 'FL', 'MD', 'UT', 'OR',
#        'MO', 'AR', 'CO', 'KS', 'MN', 'NV', 'ID', 'IN', 'IA', 'VA', 'KY',
#        'LA', 'HI', 'WV', 'WI', 'SC', 'NE', 'DE', 'DC', 'AL', 'VT', 'RI',
#        'OK', 'ME', 'MS', 'MT', 'SD', 'ND', 'AK', 'WY'], dtype=object)

# %%
df['region'].unique()
# Out:
# array(['Seattle', 'Los Angeles', 'SF Bay', ..., 'Parnell Auckland',
#        'Jalandhar City', 'D.I.Khan'], dtype=object)

# %%
#Status for rows where investment columns are empty
df.loc[df['investment_rounds'].isna(), 'status'].value_counts()
# Out:
# status
# operating    181188
# acquired       9281
# closed         2573
# ipo             920
# Name: count, dtype: int64

# %%
#Status for rows where funding amount columns are empty
df.loc[df['funding_total_usd'].isna(), 'status'].value_counts()
# Out:
# status
# operating    160130
# acquired       7059
# closed          836
# ipo             654
# Name: count, dtype: int64

# %%
path = "/content/drive/MyDrive/BTT - G&M1A/G&M/gm_project1_synthetic_startups.csv"

df = pd.read_csv(path, low_memory=False)

df.head()
# Out:
#                              company_id    company_name founded_date country  \
# 0  ddc59bd7-fb40-4955-a110-472b1de3b59e         SkyTech   2025-08-21     USA
# 1  5cc0cdd6-288c-4cda-bb84-da69e6266027  BetaIndustries   2022-03-12     USA
# 2  d98f79b7-988b-4af9-8f07-c63eebc7965e   AlphaDynamics   2023-08-25     USA
# 3  599f43ab-237f-4ca5-bd49-f40e63d6db66         SkyData   2021-06-20     USA
# 4  56cfc88f-cb85-4fc3-a098-888d004d2a80     VertexForge   2017-12-20     USA
#
#   state         city    zip industry_sector  sector_growth_rate_pct  \
# 0    MN  Springfield  69048       Logistics                    7.12
# 1    LA      Clinton  69950       Logistics                   13.46
# 2    DC  Springfield  96305      Enterprise                   14.25
# 3    MT     Franklin  87242         Fintech                   19.97
# 4    CO       Aurora  76086         Fintech                   11.12
#
#    headcount  ...  enterprise_contracts_count patents_count  \
# 0         28  ...                           4             0
# 1          1  ...                           5             1
# 2         32  ...                           3             1
# 3         37  ...                           6             1
# 4         36  ...                           8             0
#
#    founder_prev_exits_count  age_months  funding_velocity_usd_per_month  \
# 0                         0         1.0                            0.00
# 1                         0        41.8                         1874.14
# 2                         0        24.3                        75948.64
# 3                         0        50.5                       431687.76
# 4                         0        92.5                      1164311.25
#
#   months_since_last_round  capital_needed_next_18m_usd  \
# 0                     NaN                   5865251.40
# 1                     NaN                   1421785.36
# 2                     2.4                   4812883.26
# 3                    32.5                         0.00
# 4                     NaN                         0.00
#
#    undercapitalized_gap_usd  undercapitalized_flag      target_outcome
# 0                5865251.40                   True  inactive_or_failed
# 1                1408532.08                   True  inactive_or_failed
# 2                4316254.89                   True    sustain_no_round
# 3                      0.00                  False    sustain_no_round
# 4                      0.00                  False  inactive_or_failed
#
# [5 rows x 39 columns]

# %%
df.columns
# Out:
# Index(['company_id', 'company_name', 'founded_date', 'country', 'state',
#        'city', 'zip', 'industry_sector', 'sector_growth_rate_pct', 'headcount',
#        'founder_count', 'stage', 'round_count', 'total_funding_usd',
#        'last_round_amount_usd', 'last_round_date', 'valuation_post_money_usd',
#        'mrr_usd', 'arr_usd', 'gross_margin_pct', 'monthly_burn_usd',
#        'cash_reserves_usd', 'runway_months', 'growth_mrr_3m_pct',
#        'churn_logo_pct', 'cac_usd', 'ltv_usd', 'ltv_cac_ratio',
#        'users_active_mau', 'enterprise_contracts_count', 'patents_count',
#        'founder_prev_exits_count', 'age_months',
#        'funding_velocity_usd_per_month', 'months_since_last_round',
#        'capital_needed_next_18m_usd', 'undercapitalized_gap_usd',
#        'undercapitalized_flag', 'target_outcome'],
#       dtype='object')

# %%
df.shape
# Out:
# (1000, 39)

# %%
df.dtypes
# Out:
# company_id                         object
# company_name                       object
# founded_date                       object
# country                            object
# state                              object
# city                               object
# zip                                 int64
# industry_sector                    object
# sector_growth_rate_pct            float64
# headcount                           int64
# founder_count                       int64
# stage                              object
# round_count                         int64
# total_funding_usd                 float64
# last_round_amount_usd             float64
# last_round_date                    object
# valuation_post_money_usd          float64
# mrr_usd                           float64
# arr_usd                           float64
# gross_margin_pct                  float64
# monthly_burn_usd                  float64
# cash_reserves_usd                 float64
# runway_months                     float64
# growth_mrr_3m_pct                 float64
# churn_logo_pct                    float64
# cac_usd                           float64
# ltv_usd                           float64
# ltv_cac_ratio                     float64
# users_active_mau                    int64
# enterprise_contracts_count          int64
# patents_count                       int64
# founder_prev_exits_count            int64
# age_months                        float64
# funding_velocity_usd_per_month    float64
# months_since_last_round           float64
# capital_needed_next_18m_usd       float64
# undercapitalized_gap_usd          float64
# undercapitalized_flag                bool
# target_outcome                     object
# dtype: object

# %%
df.isnull().sum()
# Out:
# company_id                          0
# company_name                        0
# founded_date                        0
# country                             0
# state                               0
# city                                0
# zip                                 0
# industry_sector                     0
# sector_growth_rate_pct              0
# headcount                           0
# founder_count                       0
# stage                               0
# round_count                         0
# total_funding_usd                   0
# last_round_amount_usd               0
# last_round_date                   274
# valuation_post_money_usd          274
# mrr_usd                             0
# arr_usd                             0
# gross_margin_pct                    0
# monthly_burn_usd                    0
# cash_reserves_usd                   0
# runway_months                       0
# growth_mrr_3m_pct                   0
# churn_logo_pct                      0
# cac_usd                             0
# ltv_usd                             0
# ltv_cac_ratio                       0
# users_active_mau                    0
# enterprise_contracts_count          0
# patents_count                       0
# founder_prev_exits_count            0
# age_months                          0
# funding_velocity_usd_per_month      0
# months_since_last_round           274
# capital_needed_next_18m_usd         0
# undercapitalized_gap_usd            0
# undercapitalized_flag               0
# target_outcome                      0
# dtype: int64
